# %% [markdown]
# ## ASSIGNMENT NO.: 06
# ### Title: Design, Development, and Performance Evaluation of an AI Model for Practical Applications (Movie Recommendation System)

# %%
import pandas as pd

# %%
movies = pd.read_csv('C:/Users/RUTUJA/OneDrive/Desktop/Datasets/AIPD/tmdb_5000_movies.csv')
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits = pd.read_csv('C:/Users/RUTUJA/OneDrive/Desktop/Datasets/AIPD/tmdb_5000_credits.csv')
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
credits.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
movies = movies.merge(credits, left_on='id', right_on='movie_id')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies = movies.drop(['title_y'], axis=1)
movies = movies.rename(columns={'title_x':'title'})

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4803, 23)

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %% [markdown]
# ### Content-Based Filtering using TF-IDF

# %%
movies['overview'] = movies['overview'].astype(str)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')

tfidf_matrix = tfidf.fit_transform(movies['overview'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(tfidf_matrix)

# %%
indices = pd.Series(movies.index, index=movies['title']).drop_duplicates()

def recommend_content(movie):

    if movie not in indices:
        return []

    idx = indices[movie]

    sim_scores = list(enumerate(cosine_sim[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:6]

    movie_indices = [i[0] for i in sim_scores]

    return list(movies['title'].iloc[movie_indices])

# %%
recommend_content("Avatar")
# Out:
# ['Apollo 18',
#  'The American',
#  'The Matrix',
#  'The Inhabited Island',
#  'Tears of the Sun']

# %% [markdown]
# ### PART 2 — Collaborative Filtering using KNN

# %%
from sklearn.feature_extraction.text import CountVectorizer
movies['combined'] = movies['overview']

cv = CountVectorizer(stop_words='english')

feature_matrix = cv.fit_transform(movies['combined'])

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors(metric='cosine', algorithm='brute')

knn.fit(feature_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def recommend_knn(movie):

    if movie not in movies['title'].values:
        return []

    index = movies[movies['title']==movie].index[0]

    distances, indices = knn.kneighbors(
        feature_matrix[index].reshape(1,-1),
        n_neighbors=6
    )

    recommended = []

    for i in indices.flatten()[1:]:
        recommended.append(movies.iloc[i].title)

    return recommended

# %%
recommend_knn("Avatar")
# Out:
# ['Apollo 18',
#  'Tears of the Sun',
#  'The American',
#  'Beowulf',
#  'The Inhabited Island']

# %%
import ast

def extract_genres(text):

    if isinstance(text, list):
        return text

    genres = []

    for i in ast.literal_eval(text):
        genres.append(i['name'])

    return genres

movies['genres'] = movies['genres'].apply(extract_genres)

# %% [markdown]
# ### Accuracy for Content-Based Filtering (TF-IDF)

# %%
total_tp = 0
total_rec = 0

sample_movies = movies['title'].sample(100)

for movie in sample_movies:

    recommended = recommend_content(movie)

    relevant = get_relevant(movie)

    tp = len(set(recommended) & relevant)

    total_tp += tp
    total_rec += len(recommended)

tfidf_accuracy = total_tp / total_rec

print("TF-IDF Total Accuracy:", tfidf_accuracy)
# Out:
# TF-IDF Total Accuracy: 0.638

# %% [markdown]
# ### Accuracy for Collaborative Filtering (KNN)

# %%
total_tp = 0
total_rec = 0

sample_movies = movies['title'].sample(100)

for movie in sample_movies:

    recommended = recommend_knn(movie)

    relevant = get_relevant(movie)

    tp = len(set(recommended) & relevant)

    total_tp += tp
    total_rec += len(recommended)

knn_accuracy = total_tp / total_rec

print("KNN Total Accuracy:", knn_accuracy)
# Out:
# KNN Total Accuracy: 0.628
